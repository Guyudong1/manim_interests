# %%
from manim import *

class II(Scene):
    def construct(self):
        t1 = Text("三大"主义"思潮", font="Microsoft YaHei", font_size=110, color=GOLD_A, weight="BOLD")
        t1.move_to(UP*4).set_opacity(0)

        self.play(t1.animate.shift(DOWN*4).set_opacity(1))
        self.wait(2)
        self.play(t1.animate.shift(DOWN*5).set_opacity(0))

        t2 = Text("符号主义", font="Microsoft YaHei", font_size=110, color=GOLD_A, weight="BOLD")
        t2.move_to(UP*4).set_opacity(0)
        tt2 = Text("符号 + 逻辑", font="Microsoft YaHei", font_size=70, color=GOLD_C, weight="BOLD")
        tt2.move_to(ORIGIN).set_opacity(0)
        ttt2 = Text("专家系统/知识图谱/逻辑回归", font="Microsoft YaHei", font_size=70, color=GOLD_C, weight="BOLD")
        ttt2.move_to(ORIGIN).set_opacity(0)

        self.play(t2.animate.shift(DOWN*4).set_opacity(1))
        self.wait(2)
        self.play(
            t2.animate.shift(UP*0.6),
            tt2.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(7)
        self.play(
            tt2.animate.shift(DOWN*0.7).set_opacity(0),
            ttt2.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(3)
        self.play(
            t2.animate.shift(DOWN*5).set_opacity(0),
            ttt2.animate.shift(DOWN*5).set_opacity(0),
        )
        self.wait(2)

        t3 = Text("连接主义", font="Microsoft YaHei", font_size=110, color=GOLD_A, weight="BOLD")
        t3.move_to(UP*4).set_opacity(0)
        tt3 = Text("Functions describe the world", font="Microsoft YaHei", font_size=60, color=GOLD_C, weight="BOLD")
        tt3.move_to(ORIGIN).set_opacity(0)
        tt31 = Text("函数 + 学习", font="Microsoft YaHei", font_size=70, color=GOLD_C, weight="BOLD")
        tt31.move_to(ORIGIN).set_opacity(0)
        ttt3 = Text("机器学习/深度学习/感知机", font="Microsoft YaHei", font_size=70, color=GOLD_C, weight="BOLD")
        ttt3.move_to(ORIGIN).set_opacity(0)

        self.play(t3.animate.shift(DOWN*4).set_opacity(1))
        self.wait(2)
        self.play(
            t3.animate.shift(UP*0.6),
            tt3.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(2)
        self.play(
            tt3.animate.shift(DOWN*0.7).set_opacity(0),
            tt31.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(7)
        self.play(
            tt31.animate.shift(DOWN*0.7).set_opacity(0),
            ttt3.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(3)
        self.play(
            t3.animate.shift(DOWN*5).set_opacity(0),
            ttt3.animate.shift(DOWN*5).set_opacity(0),
        )
        self.wait(2)

        t4 = Text("行为主义", font="Microsoft YaHei", font_size=110, color=GOLD_A, weight="BOLD")
        t4.move_to(UP*4).set_opacity(0)
        tt4 = Text("行为 + 适应", font="Microsoft YaHei", font_size=70, color=GOLD_C, weight="BOLD")
        tt4.move_to(ORIGIN).set_opacity(0)
        ttt4 = Text("强化学习/进化算法/群体多智能体", font="Microsoft YaHei", font_size=60, color=GOLD_C, weight="BOLD")
        ttt4.move_to(ORIGIN).set_opacity(0)
        self.play(t4.animate.shift(DOWN*4).set_opacity(1))
        self.wait(2)
        self.play(
            t4.animate.shift(UP*0.6),
            tt4.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(7)
        self.play(
            tt4.animate.shift(DOWN*0.7).set_opacity(0),
            ttt4.animate.shift(DOWN*0.7).set_opacity(1)
        )
        self.wait(3)
        self.play(
            t4.animate.shift(DOWN*5).set_opacity(0),
            ttt4.animate.shift(DOWN*5).set_opacity(0),
        )
        self.wait(2)
